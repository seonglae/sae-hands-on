# %%
# instantiate an object to hold activations from a dataset
from sae_lens import ActivationsStore

# a convenient way to instantiate an activation store is to use the from_sae method
activation_store = ActivationsStore.from_sae(
    model=model,
    sae=sae,
    streaming=True,
    # fairly conservative parameters here so can use same for larger
    # models without running out of memory.
    store_batch_size_prompts=8,
    train_batch_size_tokens=4096,
    n_batches_in_buffer=32,
    device=device,
)
# Out:
# /cs/student/projects2/aisd/2024/seongcho/miniconda3/envs/sae/lib/python3.10/site-packages/sae_lens/training/activations_store.py:246: UserWarning:
#
# Dataset is not tokenized. Pre-tokenizing will improve performance and allows for more control over special tokens. See https://jbloomaus.github.io/SAELens/training_saes/#pretokenizing-datasets for more info.

# %%
def list_flatten(nested_list):
    return [x for y in nested_list for x in y]


# A very handy function Neel wrote to get context around a feature activation
def make_token_df(tokens, len_prefix=5, len_suffix=3, model=model):
    str_tokens = [model.to_str_tokens(t) for t in tokens]
    unique_token = [
        [f"{s}/{i}" for i, s in enumerate(str_tok)] for str_tok in str_tokens
    ]

    context = []
    prompt = []
    pos = []
    label = []
    for b in range(tokens.shape[0]):
        for p in range(tokens.shape[1]):
            prefix = "".join(str_tokens[b][max(0, p - len_prefix) : p])
            if p == tokens.shape[1] - 1:
                suffix = ""
            else:
                suffix = "".join(
                    str_tokens[b][p + 1 : min(tokens.shape[1] - 1, p + 1 + len_suffix)]
                )
            current = str_tokens[b][p]
            context.append(f"{prefix}|{current}|{suffix}")
            prompt.append(b)
            pos.append(p)
            label.append(f"{b}/{p}")
    # print(len(batch), len(pos), len(context), len(label))
    return pd.DataFrame(
        dict(
            str_tokens=list_flatten(str_tokens),
            unique_token=list_flatten(unique_token),
            context=context,
            prompt=prompt,
            pos=pos,
            label=label,
        )
    )

# %%
# finding max activating examples is a bit harder. To do this we need to calculate feature activations for a large number of tokens
feature_list = torch.randint(0, sae.cfg.d_sae, (100,))
examples_found = 0
all_fired_tokens = []
all_feature_acts = []
all_reconstructions = []
all_token_dfs = []

total_batches = 100
batch_size_prompts = activation_store.store_batch_size_prompts
batch_size_tokens = activation_store.context_size * batch_size_prompts
pbar = tqdm(range(total_batches))
for i in pbar:
    tokens = activation_store.get_batch_tokens()
    tokens_df = make_token_df(tokens)
    tokens_df["batch"] = i

    flat_tokens = tokens.flatten()

    _, cache = model.run_with_cache(
        tokens, stop_at_layer=sae.cfg.hook_layer + 1, names_filter=[sae.cfg.hook_name]
    )
    sae_in = cache[sae.cfg.hook_name]
    feature_acts = sae.encode(sae_in).squeeze()

    feature_acts = feature_acts.flatten(0, 1)
    fired_mask = (feature_acts[:, feature_list]).sum(dim=-1) > 0
    fired_tokens = model.to_str_tokens(flat_tokens[fired_mask])
    reconstruction = feature_acts[fired_mask][:, feature_list] @ sae.W_dec[feature_list]

    token_df = tokens_df.iloc[fired_mask.cpu().nonzero().flatten().numpy()]
    all_token_dfs.append(token_df)
    all_feature_acts.append(feature_acts[fired_mask][:, feature_list])
    all_fired_tokens.append(fired_tokens)
    all_reconstructions.append(reconstruction)

    examples_found += len(fired_tokens)
    # print(f"Examples found: {examples_found}")
    # update description
    pbar.set_description(f"Examples found: {examples_found}")

# flatten the list of lists
all_token_dfs = pd.concat(all_token_dfs)
all_fired_tokens = list_flatten(all_fired_tokens)
all_reconstructions = torch.cat(all_reconstructions)
all_feature_acts = torch.cat(all_feature_acts)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1217 > 1024). Running this sequence through the model will result in indexing errors
# Examples found: 23865: 100%|██████████| 100/100 [00:03<00:00, 27.53it/s]

# %%
feature_acts_df = pd.DataFrame(
    all_feature_acts.detach().cpu().numpy(),
    columns=[f"feature_{i}" for i in feature_list],
)
feature_acts_df.shape
# Out:
# (23865, 100)

# %%
feature_idx = 0
# get non-zero activations

all_positive_acts = all_feature_acts[all_feature_acts[:, feature_idx] > 0][
    :, feature_idx
].detach()
prop_positive_activations = (
    100 * len(all_positive_acts) / (total_batches * batch_size_tokens)
)

px.histogram(
    all_positive_acts.cpu(),
    nbins=50,
    title=f"Histogram of positive activations - {prop_positive_activations:.3f}% of activations were positive",
    labels={"value": "Activation"},
    width=800,
)
# Out:
# <div>                            <div id="dd83c8bf-aae3-4dad-97b7-d02e0edd2d14" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd83c8bf-aae3-4dad-97b7-d02e0edd2d14")) {                    Plotly.newPlot(                        "dd83c8bf-aae3-4dad-97b7-d02e0edd2d14",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0\u003cbr\u003eActivation=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","nbinsx":50,"offsetgroup":"0","orientation":"v","showlegend":true,"x":[0.54636914,0.36121896,2.5110445,0.6505668,0.230033,0.2504492,0.010166828,1.056723,0.0680912,0.015002947,0.27534074,0.26338214,0.438559,0.059173476,0.11815342,0.24011438,1.0005709,1.8595062,0.24029766,0.5932489,1.265241,0.51805484,0.26241854,0.11299747,0.4056154,0.7349205,0.15391962,2.1517465,0.23422562,0.5018003,0.01652592,0.9635138,0.14217901,0.5729236,0.5237506,0.86096865,0.85588294,0.46517068,0.13988745,0.64300746,0.7326401,0.2540855,0.6946044,0.8222597,0.08111347,0.5590451,0.30752096,0.24336527,0.1823589,1.2227317,0.053227503,0.08919951,0.09112562,0.20750771,0.9237635,0.15963799,0.29063502,1.2289177,0.94830805,0.4313528,0.23642077,0.69856817,0.033094164,0.6819557,0.011977937,0.6529487,0.38536462,2.4596076,0.38550642,0.20488684,0.31271556,0.14056134,0.51761854,0.7600877,0.3370072,0.7755936,0.40106156,0.70506877,0.7218032,0.12816465,0.48452795,0.05647221,0.58911127,0.351773,0.45903838,0.149624,0.2151094,0.8758191,0.5958922,0.9525092,0.46779418,0.07496582,0.026929628,0.96870786,0.22032358,0.008055713,0.1767699,0.71564335,0.09697521,0.0898246,0.017011728,0.25131035,0.24808227,0.16807492,0.4838276,0.7977448,0.24870111,1.5115005,0.26594895,0.05327795,0.6639938,0.1618394,0.24480288,0.43745536,0.26447037,0.34121364,0.11491367,0.099231064,1.88087,0.61899877,1.3066282,0.10918641,0.9767991,1.7016122,0.107062325,0.7320445,1.2651253,0.1760438,0.6278068,0.21475549,0.3491108,0.98405164,0.27416772,0.06860998,0.53078765,0.07136333,0.17968608,0.22438006,1.0050524,0.26795882,0.45546496,0.1873428,0.24704368,0.20357378,1.6656669,0.5640696,0.025327366,0.3549372,0.36369854,0.43525073,0.5039242,0.34564322,0.4479463,0.9769297,0.07199022,0.11015414,0.33982432,0.6437995,1.3671116,0.0067811795,0.26353365,0.3541167,0.040172298,0.39065856,0.18148597,0.2781039,0.09824698,0.34935337,0.16658702,0.028403815,0.6193322,0.13582464,0.41242284,0.059979003,1.7692568,0.6635427,0.77751124,0.09646295,0.32426623,0.8039502,0.3933111,0.5235995,0.54748154,0.22700371,0.07430631,0.1081665,0.86334264,0.24520306,1.9308478,0.82843363,1.7761188,1.1065063,0.15974139,1.0274781,0.23284729,0.8466479,0.4284644,0.5318525,0.044783127,0.5455265,0.9963649,0.18668407,0.20119484,0.6287257,0.5153764,1.284977,1.0415337,0.4463266,0.74946624,0.6253322,0.0548481,0.5595028,0.6985176,0.108421385,0.81352824,0.38647878,0.87455744,0.45667815,0.45435452,0.065580636,0.55001825,1.3687006,1.4047791,0.13485983,0.28310254,1.8366969,0.13312998,0.84882486,0.816632,1.0066121,2.9459975,0.04679976,0.17897926,0.36377704,0.44000304,1.7097237,0.8450272,1.0865322,0.32532012,2.8168492,0.15881266,0.59474593,0.4929204,0.4169181,0.036117923,0.2742387,0.016133767,0.25880224,0.5337309,0.06623557,0.022656132,0.8959156,0.37677142,1.2336287,0.019844886,0.1585917,0.94877416,0.3743147,0.23921789,0.8013972,0.48583168,0.42538768,0.17887513,0.40636003,0.52698666,2.3671105,0.4514994,0.38065627,0.26748848,0.55706525,0.21141191,0.1103265,0.038886447,1.7892872,0.42341214,0.56792814,0.88597393,1.3643904,1.1674631,0.29179204,0.78827965,0.052814428,1.2751181,0.43613973,0.68749297,0.26420903,1.3978332,1.3968364,0.19746126,0.6694552,0.04586273,2.1445045,1.3750092,0.77793014,1.1551156,0.96347564,0.230099 ...

# %%
top_10_activations = feature_acts_df.sort_values(
    f"feature_{feature_list[0]}", ascending=False
).head(10)
all_token_dfs.iloc[
    top_10_activations.index
]  # TODO: double check this is working correctly
# Out:
#     str_tokens unique_token  \
# 561          7         7/49
# 812       even      even/44
# 665      Found     Found/25
# 458    quality   quality/74
# 220       time      time/92
# 703        New       New/63
# 155          s         s/27
# 961        all       all/65
# 463        all       all/79
# 54        know      know/54
#
#                                                context  prompt  pos label  \
# 561  <|endoftext|>This article is over| 7| years old\n       4   49  4/49
# 812  \nWhat makes the situation| even| more perplexing       6   44  6/44
# 665           David Kelly inquest\n\n|Found| in woods:       5   25  5/25
# 458           Criticisms of the| quality| of the study       3   74  3/74
# 220             by his teammate at the| time|, Ian Del       1   92  1/92
# 703                )\n\nName Current| New| Kenichi Kom       5   63  5/63
# 155                       ers.\n\nTurn|s| out The Game       1   27  1/27
# 961               UCLA. If any or| all| of these teams       7   65  7/65
# 463   said Porter expects to have| all| the needed ...       3   79  3/79
# 54              \nTo those in the| know|, the campaign       0   54  0/54
#
#      batch
# 561     92
# 812     65
# 665     93
# 458     37
# 220     49
# 703      8
# 155     17
# 961     60
# 463     98
# 54       9

# %%
print(f"Shape of the decoder weights {sae.W_dec.shape})")
print(f"Shape of the model unembed {model.W_U.shape}")
projection_matrix = sae.W_dec @ model.W_U
print(f"Shape of the projection matrix {projection_matrix.shape}")

# then we take the top_k tokens per feature and decode them
top_k = 10
# let's do this for 100 random features
_, top_k_tokens = torch.topk(projection_matrix[feature_list], top_k, dim=1)


feature_df = pd.DataFrame(
    top_k_tokens.cpu().numpy(), index=[f"feature_{i}" for i in feature_list]
).T
feature_df.index = [f"token_{i}" for i in range(top_k)]
feature_df.applymap(lambda x: model.tokenizer.decode(x))
# Out:
# Shape of the decoder weights torch.Size([24576, 768]))
# Shape of the model unembed torch.Size([768, 50257])
# Shape of the projection matrix torch.Size([24576, 50257])
# /tmp/ipykernel_1411845/1957071427.py:16: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#         feature_5269      feature_24224 feature_16715 feature_14262  \
# token_0       atform            puberty        Stores    altogether
# token_1          TAG             phases         malls            %.
# token_2         hiro  inventoryQuantity        stores            '.
# token_3          raq          attrition       shelves            }.
# token_4       lement             stages      shoppers           .).
# token_5          rik            enhagen         store           due
# token_6          hra               odan      Shopping            ].
# token_7         neau             wrench       Walmart          lest
# token_8          aml            Perkins      shopping       anymore
# token_9         liam              hoops         Store           '."
#
#          feature_21566 feature_19003   feature_11907 feature_4366  \
# token_0   Technologies          bags            than      raining
# token_1    Corporation       happens       efficient          beh
# token_2            CEO          hots       stringent       happen
# token_3           Corp     happening            Than         iner
# token_4         Stores           bag      meaningful         etsk
# token_5       Holdings         iness      aggressive         dawn
# token_6   subsidiaries          ious       expensive   impossible
# token_7     subsidiary           EMS   sophisticated         happ
# token_8     executives          uits             HUD     happened
# token_9        Company             y         drastic      unclear
#
#         feature_22045    feature_3438  ...  feature_23475  feature_10831  \
# token_0          Chem            uate  ...         namely       resident
# token_1         Games           imize  ...            viz        natives
# token_2          Gold            pell  ...      including    businessman
# token_3         swers        omething  ...           plus   entrepreneur
# token_4          Site          livion  ...         albeit          Times
# token_5      Textures         balance  ...       totaling       Symphony
# token_6       ventory    explanations  ...      excluding         native
# token_7            Fa           urate  ...   respectively         bureau
# token_8            DX   clarification  ...      excluding    billionaire
# token_9        elaide         TEXTURE  ...        notably      residents
#
#         feature_1336 feature_12483 feature_9142 feature_21585 feature_17427  \
# token_0           sg           LLP          bag         alian          ller
# token_1        adish    subsidiary         bags       enegger         llers
# token_2       emonic           LTD         iest        VIDEOS          ptic
# token_3          haw       strives         bike            Jr          vich
# token_4       ionage       founder          sie            Jr         lling
# token_5        shire     partnered        iness         ellen            ls
# token_6     ":""},{"       ONSORED         dirt        iciary         letal
# token_7       isters           Inc        brush       enhagen        jriwal
# token_8       bright      founders         shed         eller         rette
# token_9      unction       Limited        oxide         uchin           rer
#
#         feature_430   feature_13040  feature_9197
# token_0          */           cause       pointer
# token_1          ${           IFIED      accuracy
# token_2          </         ifiable         antry
# token_3        ..."               子     hetically
# token_4        ..."            luck           (%)
# token_5          {}  soDeliveryDate    percentage
# token_6           %           OTHER   coefficient
# token_7          "}               �      pointers
# token_8         "))       ification         point
# token_9         )</           whiff          ttle
#
# [10 rows x 100 columns]

# %%
# only valid for res-jb resid_pre 7.
# Josh Engel's emailed us these lists.
day_of_the_week_features = [2592, 4445, 4663, 4733, 6531, 8179, 9566, 20927, 24185]
# months_of_the_year = [3977, 4140, 5993, 7299, 9104, 9401, 10449, 11196, 12661, 14715, 17068, 17528, 19589, 21033, 22043, 23304]
# years_of_10th_century = [1052, 2753, 4427, 6382, 8314, 9576, 9606, 13551, 19734, 20349]

feature_list = day_of_the_week_features

examples_found = 0
all_fired_tokens = []
all_feature_acts = []
all_reconstructions = []
all_token_dfs = []

total_batches = 100
batch_size_prompts = activation_store.store_batch_size_prompts
batch_size_tokens = activation_store.context_size * batch_size_prompts
pbar = tqdm(range(total_batches))
for i in pbar:
    tokens = activation_store.get_batch_tokens()
    tokens_df = make_token_df(tokens)
    tokens_df["batch"] = i

    flat_tokens = tokens.flatten()

    _, cache = model.run_with_cache(
        tokens, stop_at_layer=sae.cfg.hook_layer + 1, names_filter=[sae.cfg.hook_name]
    )
    sae_in = cache[sae.cfg.hook_name]
    feature_acts = sae.encode(sae_in).squeeze()

    feature_acts = feature_acts.flatten(0, 1)
    fired_mask = (feature_acts[:, feature_list]).sum(dim=-1) > 0
    fired_tokens = model.to_str_tokens(flat_tokens[fired_mask])
    reconstruction = feature_acts[fired_mask][:, feature_list] @ sae.W_dec[feature_list]

    token_df = tokens_df.iloc[fired_mask.cpu().nonzero().flatten().numpy()]
    all_token_dfs.append(token_df)
    all_feature_acts.append(feature_acts[fired_mask][:, feature_list])
    all_fired_tokens.append(fired_tokens)
    all_reconstructions.append(reconstruction)

    examples_found += len(fired_tokens)
    # print(f"Examples found: {examples_found}")
    # update description
    pbar.set_description(f"Examples found: {examples_found}")

# flatten the list of lists
all_token_dfs = pd.concat(all_token_dfs)
all_fired_tokens = list_flatten(all_fired_tokens)
all_reconstructions = torch.cat(all_reconstructions)
all_feature_acts = torch.cat(all_feature_acts)
# Out:
# Examples found: 164: 100%|██████████| 100/100 [00:03<00:00, 28.76it/s]

# %%
# do PCA on reconstructions
from sklearn.decomposition import PCA
import plotly.express as px

pca = PCA(n_components=3)
pca_embedding = pca.fit_transform(all_reconstructions.detach().cpu().numpy())

pca_df = pd.DataFrame(pca_embedding, columns=["PC1", "PC2", "PC3"])
pca_df["tokens"] = all_fired_tokens
pca_df["context"] = all_token_dfs.context.values


px.scatter(
    pca_df,
    x="PC2",
    y="PC3",
    hover_data=["context"],
    hover_name="tokens",
    height=800,
    width=1200,
    color="tokens",
    title="PCA Subspace Reconstructions",
).show()
# Out:
# <div>                            <div id="6d352039-a0be-48fa-a509-5ccc62f1ff97" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d352039-a0be-48fa-a509-5ccc62f1ff97")) {                    Plotly.newPlot(                        "6d352039-a0be-48fa-a509-5ccc62f1ff97",                        [{"customdata":[[" Border��s Books| yesterday|, I asked"],[" Fisher posted to the group| yesterday| — apologizing for"],[" Penrith, Sydney| yesterday|.\n\n"],[" Sydney International Regatta Centre| yesterday| to listen to"],[" off the assembly line earlier| yesterday| (June."],[" winner of the newspaper competition| yesterday| and asking if"],[" wrongdoing.\n\nJust| yesterday|, LAUSD"]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etokens= yesterday\u003cbr\u003ePC2=%{x}\u003cbr\u003ePC3=%{y}\u003cbr\u003econtext=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":[" yesterday"," yesterday"," yesterday"," yesterday"," yesterday"," yesterday"," yesterday"],"legendgroup":" yesterday","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":" yesterday","orientation":"v","showlegend":true,"x":[-2.6354413,-3.0637212,-2.4039967,-3.428999,-2.4800735,-3.2088306,-2.0894427],"xaxis":"x","y":[11.345536,11.749268,10.655049,12.43692,11.168204,11.665381,9.34396],"yaxis":"y","type":"scatter"},{"customdata":[[" Bob Barr released a statement| today| criticizing the bung"],["The extraordinary figures are published| today| ahead Tuesday�"],[". He worked some team| today|.��"],[" (FSAI)| today| reminded people the"],["oslav Hruska said| today|.\n\n"],["\u003c|endoftext|\u003eovakia| today| joined Poland in"],[" and immoral laws, society| today|, would be"],[" those items on the menu| today|, but there"],[" they had to say on| today|��s"],[" past are still haunting us| today|;"],[" afternoon showers pop up both| today| and Thursday."],[" seeing more people calling us| today| to make an"]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etokens= today\u003cbr\u003ePC2=%{x}\u003cbr\u003ePC3=%{y}\u003cbr\u003econtext=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":[" today"," today"," today"," today"," today"," today"," today"," today"," today"," today"," today"," today"],"legendgroup":" today","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":" today","orientation":"v","showlegend":true,"x":[-0.6380796,-0.10401593,-0.3021211,-0.0058336905,-0.060638677,-0.04300557,-0.15514666,-0.4585224,0.011184979,-0.0646218,0.2627056,-0.17226212],"xaxis":"x","y":[0.19670431,-0.717255,-0.24025084,-0.88527703,-0.9325321,-0.69013876,-0.62975264,-0.11057586,-1.33262,-0.7846711,1.1067368,-0.6004626],"yaxis":"y","type":"scatter"},{"customdata":[[" 9\u002f11. This| anything| goes attitude needs"]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etokens= anything\u003cbr\u003ePC2=%{x}\u003cbr\u003ePC3=%{y}\u003cbr\u003econtext=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":[" anything"],"legendgroup":" anything","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":" anything","orientation":"v","showlegend":true,"x":[0.036616933],"xaxis":"x","y":[-0.86405927],"yaxis":"y","type":"scatter"},{"customdata":[[" and final presidential debate on| Wednesday| night. But"],[" the revenue collectors. On| Wednesday|, a Poc"],[" over 60s, and| Wednesday|��s"],[" the Houston Airport System reported| Wednesday|.\n\n"],[" according to the notice published| Wednesday|. \"The"],["pe said in an interview| Wednesday|.\n\n"],[",\" he told journalists on| Wednesday|.\n\n"],[" an audacious plan on| Wednesday| to land an"],[" the full moon  ...
